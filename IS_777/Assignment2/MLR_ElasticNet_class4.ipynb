# %%
import numpy as np
import glob
import datetime
from datetime import date
from datetime import timedelta
import datetime
from dateutil.relativedelta import relativedelta
from datetime import datetime
import pandas as pd
import os
from netCDF4 import Dataset
import netCDF4 as nc
import matplotlib.pyplot as plt# importing modules and packageslas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing

# %%
#Below three blocks are for checking the hyperparamets of alpha

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

def getCheckRidge(X_train_std,X_test_std,y_train,y_test):

    xx = []
    yy = []
    zz = []
    

    for i in range(1, 4000, 1):

        ridge = Ridge(alpha=i/10)
        ridge.fit(X_train_std, y_train)
        xx.append(i/10)
        yy.append(ridge.score(X_train_std, y_train))
        zz.append(ridge.score(X_test_std, y_test))

    # Create the plot with labels
    plt.plot(xx, yy, c='k', label='Training Score')  # Add label for the training score
    plt.plot(xx, zz, c='b', label='Test Score')  # Add label for the test score
    plt.title('Ridge')


    print('which score of alpha it is is maximum======', xx[np.argmax(zz)])
    print(np.argmax(zz))

    # Add a legend
    plt.legend()

    # Show the plot
    plt.show()




# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values


print(len(X[0]))



sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()






# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

#X_train, X_test, y_train, y_test  = X_std[0:int(len(X_std)*0.8)], X_std[int(len(X_std)*0.8):],y_std[0:int(len(X_std)*0.8)],y_std[int(len(X_std)*0.8):]




getCheckRidge(X_train,X_test,y_train,y_test)
# Out:
# 13
# which score of alpha it is is maximum====== 0.1
# 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

def getCheckLasso(X_train_std,X_test_std,y_train,y_test):

    xx = []
    yy = []
    zz = []
    

    for i in range(1, 4000, 1):

        ridge = Lasso(alpha=i/10)
        ridge.fit(X_train_std, y_train)
        xx.append(i/10)
        yy.append(ridge.score(X_train_std, y_train))
        zz.append(ridge.score(X_test_std, y_test))

    # Create the plot with labels
    plt.plot(xx, yy, c='k', label='Training Score')  # Add label for the training score
    plt.plot(xx, zz, c='b', label='Test Score')  # Add label for the test score
    plt.title('Lasso')


    print('which score of alpha it is is maximum======', xx[np.argmax(zz)])
    print(np.argmax(zz))

    # Add a legend
    plt.legend()

    # Show the plot
    plt.show()




# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values


print(len(X[0]))



sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()






# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

#X_train, X_test, y_train, y_test  = X_std[0:int(len(X_std)*0.8)], X_std[int(len(X_std)*0.8):],y_std[0:int(len(X_std)*0.8)],y_std[int(len(X_std)*0.8):]




getCheckLasso(X_train,X_test,y_train,y_test)
# Out:
# 13
# which score of alpha it is is maximum====== 0.1
# 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

def getCheckElasticnet(X_train_std,X_test_std,y_train,y_test):

    xx = []
    yy = []
    zz = []
    

    for i in range(1, 4000, 1):

        ridge = ElasticNet(alpha=i/10, l1_ratio=0.5) 
        ridge.fit(X_train_std, y_train)
        xx.append(i/10)
        yy.append(ridge.score(X_train_std, y_train))
        zz.append(ridge.score(X_test_std, y_test))

    # Create the plot with labels
    plt.plot(xx, yy, c='k', label='Training Score')  # Add label for the training score
    plt.plot(xx, zz, c='b', label='Test Score')  # Add label for the test score
    plt.title('ElasticNet')


    print('which score of alpha it is is maximum======', xx[np.argmax(zz)])
    print(np.argmax(zz))

    # Add a legend
    plt.legend()

    # Show the plot
    plt.show()




# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values


print(len(X[0]))



sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()






# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

#X_train, X_test, y_train, y_test  = X_std[0:int(len(X_std)*0.8)], X_std[int(len(X_std)*0.8):],y_std[0:int(len(X_std)*0.8)],y_std[int(len(X_std)*0.8):]




getCheckElasticnet(X_train,X_test,y_train,y_test)
# Out:
# 13
# which score of alpha it is is maximum====== 0.1
# 0

# %%
#1. Please use the data to develop the models among MLR, RL1, L2, and Elastic net. You the first 80% of the data to train and the last 20% of the data to test. 20
#2. Please compare the coefficient of determination, spearman's rank correlation, and MSE between MLR< L1, L2, and Elastic net. Also show the perform residual analysis for each of them. 10
#3. Which model is the best and why do you arrive to that decision? 5

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt


# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values






sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()





# Split the data into training and testing sets (80% training, 20% testing)
#X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

X_train, X_test, y_train, y_test  = X_std[0:int(len(X_std)*0.8)], X_std[int(len(X_std)*0.8):],y_std[0:int(len(X_std)*0.8)],y_std[int(len(X_std)*0.8):]

# Initialize and train the models
mlr = LinearRegression()
mlr.fit(X_train, y_train)

lasso = Lasso(alpha=0.1)  # You can tune the alpha parameter
lasso.fit(X_train, y_train)

ridge = Ridge(alpha=0.1)  # You can tune the alpha parameter
ridge.fit(X_train, y_train)

elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)  # You can tune alpha and l1_ratio
elastic_net.fit(X_train, y_train)

# Make predictions on the test set
y_pred_mlr = mlr.predict(X_test)
y_pred_lasso = lasso.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_elastic_net = elastic_net.predict(X_test)

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name):
    r2 = r2_score(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    print(f"{model_name} - R-squared: {r2:.2f}")
    print(f"{model_name} - Spearman's Rank Correlation: {spearman_corr:.2f}")
    print(f"{model_name} - Mean Squared Error: {mse:.2f}")
    return r2, spearman_corr, mse

print("Multiple Linear Regression:")
r2_mlr, spearman_mlr, mse_mlr = evaluate_model(y_test, y_pred_mlr, "Multiple Linear Regression")

print("\nLasso:")
r2_lasso, spearman_lasso, mse_lasso = evaluate_model(y_test, y_pred_lasso, "Lasso")

print("\nRidge:")
r2_ridge, spearman_ridge, mse_ridge = evaluate_model(y_test, y_pred_ridge, "Ridge")

print("\nElastic Net:")
r2_elastic_net, spearman_elastic_net, mse_elastic_net = evaluate_model(y_test, y_pred_elastic_net, "Elastic Net")

# Perform residual analysis for each model
def residual_analysis(y_true, y_pred, model_name):
    residuals = y_true - y_pred
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(y_pred, residuals)
    plt.title(f"{model_name} - Residual Plot")
    plt.xlabel("Predicted Values")
    plt.ylabel("Residuals")
    
    plt.subplot(1, 2, 2)
    plt.hist(residuals, bins=30)
    plt.title(f"{model_name} - Residual Histogram")
    plt.xlabel("Residuals")
    plt.ylabel("Frequency")
    
    plt.show()

residual_analysis(y_test, y_pred_mlr, "Multiple Linear Regression")
residual_analysis(y_test, y_pred_lasso, "Lasso")
residual_analysis(y_test, y_pred_ridge, "Ridge")
residual_analysis(y_test, y_pred_elastic_net, "Elastic Net")
print(len(y_train))
print(len(y_test))
# Out:
# Multiple Linear Regression:
# Multiple Linear Regression - R-squared: -0.22
# Multiple Linear Regression - Spearman's Rank Correlation: 0.61
# Multiple Linear Regression - Mean Squared Error: 0.39
#
# Lasso:
# Lasso - R-squared: -0.20
# Lasso - Spearman's Rank Correlation: 0.53
# Lasso - Mean Squared Error: 0.38
#
# Ridge:
# Ridge - R-squared: -0.22
# Ridge - Spearman's Rank Correlation: 0.61
# Ridge - Mean Squared Error: 0.39
#
# Elastic Net:
# Elastic Net - R-squared: -0.10
# Elastic Net - Spearman's Rank Correlation: 0.56
# Elastic Net - Mean Squared Error: 0.35
# 404
# 102

# %%
#4. Now, divide the data to train the model for the last 80% of the data and test using first 20% of the data to develop MLR, RL1, L2, and Elastic net models .15


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt


# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values






sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()





# Split the data into training and testing sets (80% training, 20% testing)
#X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

X_train, X_test, y_train, y_test  = X_std[102:],X_std[0:102], y_std[102:], y_std[0:102] # 102 is 20%

print(len(y_train))
print(len(y_test))

# Initialize and train the models
mlr = LinearRegression()
mlr.fit(X_train, y_train)

lasso = Lasso(alpha=0.1)  # You can tune the alpha parameter
lasso.fit(X_train, y_train)

ridge = Ridge(alpha=0.1)  # You can tune the alpha parameter
ridge.fit(X_train, y_train)

elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)  # You can tune alpha and l1_ratio
elastic_net.fit(X_train, y_train)

# Make predictions on the test set
y_pred_mlr = mlr.predict(X_test)
y_pred_lasso = lasso.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_elastic_net = elastic_net.predict(X_test)

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name):
    r2 = r2_score(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    print(f"{model_name} - R-squared: {r2:.2f}")
    print(f"{model_name} - Spearman's Rank Correlation: {spearman_corr:.2f}")
    print(f"{model_name} - Mean Squared Error: {mse:.2f}")
    return r2, spearman_corr, mse

print("Multiple Linear Regression:")
r2_mlr, spearman_mlr, mse_mlr = evaluate_model(y_test, y_pred_mlr, "Multiple Linear Regression")

print("\nLasso:")
r2_lasso, spearman_lasso, mse_lasso = evaluate_model(y_test, y_pred_lasso, "Lasso")

print("\nRidge:")
r2_ridge, spearman_ridge, mse_ridge = evaluate_model(y_test, y_pred_ridge, "Ridge")

print("\nElastic Net:")
r2_elastic_net, spearman_elastic_net, mse_elastic_net = evaluate_model(y_test, y_pred_elastic_net, "Elastic Net")
# Out:
# 404
# 102
# Multiple Linear Regression:
# Multiple Linear Regression - R-squared: 0.64
# Multiple Linear Regression - Spearman's Rank Correlation: 0.85
# Multiple Linear Regression - Mean Squared Error: 0.15
#
# Lasso:
# Lasso - R-squared: 0.73
# Lasso - Spearman's Rank Correlation: 0.90
# Lasso - Mean Squared Error: 0.11
#
# Ridge:
# Ridge - R-squared: 0.64
# Ridge - Spearman's Rank Correlation: 0.85
# Ridge - Mean Squared Error: 0.15
#
# Elastic Net:
# Elastic Net - R-squared: 0.73
# Elastic Net - Spearman's Rank Correlation: 0.90
# Elastic Net - Mean Squared Error: 0.11

# %%
# 5. Please choose 80% of the data randomly to train the models and rest 20% of the random data to test the model. +5


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np


from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
import matplotlib.pyplot as plt


# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Split the data into features (X) and target variable (y)
X = df.iloc[:, :-1].values

y = df['MEDV'].values






sc_x = StandardScaler()
sc_y = StandardScaler()
X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()





# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_std, y_std, test_size=0.2, random_state=42)

#X_train, X_test, y_train, y_test  = X_std[102:],X_std[0:102], y_std[102:], y_std[0:102] # 102 is 20%

print(len(y_train))
print(len(y_test))

# Initialize and train the models
mlr = LinearRegression()
mlr.fit(X_train, y_train)

lasso = Lasso(alpha=0.1)  # You can tune the alpha parameter
lasso.fit(X_train, y_train)

ridge = Ridge(alpha=0.1)  # You can tune the alpha parameter
ridge.fit(X_train, y_train)

elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)  # You can tune alpha and l1_ratio
elastic_net.fit(X_train, y_train)

# Make predictions on the test set
y_pred_mlr = mlr.predict(X_test)
y_pred_lasso = lasso.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_elastic_net = elastic_net.predict(X_test)

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name):
    r2 = r2_score(y_true, y_pred)
    spearman_corr, _ = spearmanr(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    print(f"{model_name} - R-squared: {r2:.2f}")
    print(f"{model_name} - Spearman's Rank Correlation: {spearman_corr:.2f}")
    print(f"{model_name} - Mean Squared Error: {mse:.2f}")
    return r2, spearman_corr, mse

print("Multiple Linear Regression:")
r2_mlr, spearman_mlr, mse_mlr = evaluate_model(y_test, y_pred_mlr, "Multiple Linear Regression")

print("\nLasso:")
r2_lasso, spearman_lasso, mse_lasso = evaluate_model(y_test, y_pred_lasso, "Lasso")

print("\nRidge:")
r2_ridge, spearman_ridge, mse_ridge = evaluate_model(y_test, y_pred_ridge, "Ridge")

print("\nElastic Net:")
r2_elastic_net, spearman_elastic_net, mse_elastic_net = evaluate_model(y_test, y_pred_elastic_net, "Elastic Net")
# Out:
# 404
# 102
# Multiple Linear Regression:
# Multiple Linear Regression - R-squared: 0.67
# Multiple Linear Regression - Spearman's Rank Correlation: 0.86
# Multiple Linear Regression - Mean Squared Error: 0.29
#
# Lasso:
# Lasso - R-squared: 0.63
# Lasso - Spearman's Rank Correlation: 0.84
# Lasso - Mean Squared Error: 0.33
#
# Ridge:
# Ridge - R-squared: 0.67
# Ridge - Spearman's Rank Correlation: 0.86
# Ridge - Mean Squared Error: 0.29
#
# Elastic Net:
# Elastic Net - R-squared: 0.63
# Elastic Net - Spearman's Rank Correlation: 0.85
# Elastic Net - Mean Squared Error: 0.32
